# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from numba import jit, cuda
@jit(target ="cuda")
# Out:
# python3: can't open file 'test_adult_data.py': [Errno 2] No such file or directory

# %%
import sys
sys.path.append("/content/drive/MyDrive/fairness_discrepancy")
# !python3 /content/drive/MyDrive/fairness_discrepancy/test_adult_data.py
import test_adult_data
test_adult_data.test_adult_data()
# Out:
# Looking for file 'adult.data' in the current directory...
# File found in current directory..
# Looking for file 'adult.test' in the current directory...
# File found in current directory..
# Loading only 10000 examples from the data
# Total data points: 10000
# # non-protected examples: 6754
# # protected examples: 3246
# Non-protected in positive class: 2080 (31%)
# Protected in positive class: 372 (11%)
# P-rule is: 37%
# iter:  100   lambda:  1   alpha:  0.5   kernel: rbf, method:  cobyla
# [0.62230064 0.16969394 0.64710854 ... 0.13785812 0.61671567 0.53923458]
# tcmalloc: large alloc 2745294848 bytes == 0x7552000 @  0x7f5b1c1751e7 0x7f5b13e9f41e 0x7f5b13eefc2b 0x7f5b13ef0240 0x7f5af92e529c 0x7f5af92e3e86 0x5a9dac 0x50a433 0x50cc96 0x507be4 0x588e5c 0x59fd0e 0x50d256 0x507be4 0x509900 0x50a2fd 0x50cc96 0x5095c8 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x507be4 0x509900 0x50a2fd 0x50beb4 0x5095c8 0x50a2fd 0x50beb4
# loss:  752.768946568478
# loss:  752.8598444822233
# loss:  752.5510856623871
# loss:  752.7205625189584
# loss:  752.3534895860578
# loss:  752.1746469383961
# loss:  751.9958929140648
# loss:  751.7560651286121
# loss:  751.5355974949879
# loss:  751.3229893020041
# loss:  751.0779515337706
# loss:  750.8631102457791
# loss:  750.6707528544647
# loss:  750.4632632788612
# loss:  750.3399141866685
# loss:  750.3826895833689
# loss:  750.1182339796474
# loss:  749.910142371295
# loss:  749.7249083920485
# loss:  749.5355332895695
# loss:  749.3033653240991
# loss:  749.10521614477
# loss:  748.892310986206
# loss:  748.6525918308232
# loss:  748.5538527799363
# loss:  748.4100649899729
# loss:  748.1250578889525
# loss:  748.0765821813288
# loss:  747.9021185453316
# loss:  747.7372988727127
# loss:  747.5284100632426
# loss:  747.2819270158483
# loss:  747.0730517808623
# loss:  747.1208022085073
# loss:  746.8412052106011
# loss:  746.6356647371331
# loss:  746.3939173310768
# loss:  746.2985532570322
# loss:  746.052794228927
# loss:  745.927298415465
# loss:  745.6900018607656
# loss:  745.4738418551314
# loss:  745.3653297574482
# loss:  745.1297882891369
# loss:  744.906439561523
# loss:  744.6618395918939
# loss:  744.4210461595684
# loss:  744.1874561263286
# loss:  743.98966445013
# loss:  743.7793157762908
# loss:  743.6763576375274
# loss:  743.4301472409584
# loss:  743.4068467295449
# loss:  743.2127874214511
# loss:  742.9654650558033
# loss:  742.759987356162
# loss:  742.5172200357656
# loss:  742.2889997376012
# loss:  742.1387453145167
# loss:  741.9183372176469
# loss:  741.7712512270656
# loss:  741.5313683130094
# loss:  741.2871725224392
# loss:  741.040509048559
# loss:  740.8971055991387
# loss:  740.6834420121975
# loss:  740.4422336025607
# loss:  740.13400493201
# loss:  740.0356245532328
# loss:  739.8406648780783
# loss:  739.5974466673742
# loss:  739.4176180220859
# loss:  739.2545405440711
# loss:  739.0491822450499
# loss:  738.8957991856944
# loss:  738.6762050956602
# loss:  738.4356506149159
# loss:  738.1424670373094
# loss:  737.9216207747745
# loss:  737.674128162847
# loss:  737.4506111701328
# loss:  737.2515396214619
# loss:  737.0374124929884
# loss:  736.8158032263868
# loss:  736.6905412170345
# loss:  736.508693389854
# loss:  736.2650479012768
# loss:  736.0160076185978
# loss:  735.8048861612809
# loss:  735.5862483309595
# loss:  735.714333269802
# loss:  735.5557965846999
# loss:  735.1259898128847
# loss:  734.8085699353919
# loss:  734.5828609050816
# loss:  734.3267293757692
# loss:  734.1762547804335
# loss:  733.9313966251711
# loss:  733.7571355096471
# loss:  733.6526596712873
# weights:  [0.00461211 1.01546335 0.02199328 ... 0.0056152  0.07177526 0.03053478]
# Optimization problem did not converge.. Check the solution returned by the optimizer.
# Returned solution is:
#      fun: 733.6526596712873
#    maxcv: 234.64393960433307
#  message: 'Did not converge to a solution satisfying the constraints. See `maxcv` for magnitude of violation.'
#     nfev: 100
#   status: 4
#  success: False
#        x: array([0.00461211, 1.01546335, 0.02199328, ..., 0.0056152 , 0.07177526,
#        0.03053478])
# Train data:
# ------------
# Train accuracy :  0.7595714285714286
# Total data points: 7000
# # non-protected examples: 4699
# # protected examples: 2301
# Non-protected in positive class: 40 (1%)
# Protected in positive class: 2 (0%)
# P-rule is: 10%
#
# Test data:
# ------------
# Test accuracy :  0.7506666666666667
# Total data points: 3000
# # non-protected examples: 2055
# # protected examples: 945
# Non-protected in positive class: 9 (0%)
# Protected in positive class: 0 (0%)
# P-rule is: 0%
# Looking for file 'adult.data' in the current directory...
# File found in current directory..
# Looking for file 'adult.test' in the current directory...
# File found in current directory..
# Loading only 10000 examples from the data
# Total data points: 10000
# # non-protected examples: 6712
# # protected examples: 3288
# Non-protected in positive class: 2101 (31%)
# Protected in positive class: 385 (12%)
# P-rule is: 37%
# iter:  10   lambda:  1   alpha:  0.5   kernel: rbf, method:  cobyla
# [0.46770126 0.18960905 0.81587908 ... 0.77984702 0.78020552 0.06527418]
# loss:  122968.46443779129
# loss:  122970.73145578403
# loss:  122971.57427414454
# loss:  122971.73609653625
# loss:  122975.1061595976
# loss:  122977.98365399905
# loss:  122980.74767902793
# loss:  122966.30729637577
# loss:  122968.76251060516
# loss:  122953.96532402138
# weights:  [3.26433459 6.52694536 7.04331747 ... 0.78019661 9.57868572 0.38471539]
# Optimization problem did not converge.. Check the solution returned by the optimizer.
# Returned solution is:
#      fun: 122953.96532402138
#    maxcv: 17743.45757518616
#  message: 'Did not converge to a solution satisfying the constraints. See `maxcv` for magnitude of violation.'
#     nfev: 10
#   status: 4
#  success: False
#        x: array([3.26433459, 6.52694536, 7.04331747, ..., 0.78019661, 9.57868572,
#        0.38471539])
# Train data:
# ------------
# Train accuracy :  0.8838571428571429
# Total data points: 7000
# # non-protected examples: 4684
# # protected examples: 2316
# Non-protected in positive class: 829 (18%)
# Protected in positive class: 121 (5%)
# P-rule is: 30%
#
# Test data:
# ------------
# Test accuracy :  0.7556666666666667
# Total data points: 3000
# # non-protected examples: 2028
# # protected examples: 972
# Non-protected in positive class: 75 (4%)
# Protected in positive class: 1 (0%)
# P-rule is: 3%

# %%
test_adult_data.test_adult_data()
# Out:
# Looking for file 'adult.data' in the current directory...
# File found in current directory..
# Looking for file 'adult.test' in the current directory...
# File found in current directory..
# Loading only 10000 examples from the data
# Total data points: 10000
# # non-protected examples: 6729
# # protected examples: 3271
# Non-protected in positive class: 2148 (32%)
# Protected in positive class: 376 (11%)
# P-rule is: 36%
# iter:  10   lambda:  1   alpha:  0.5   kernel: rbf, method:  cobyla
# [0.49102504 0.16496399 0.37105516 ... 0.66816091 0.96595228 0.32368878]
# loss:  122534.53588108109
# loss:  122535.95345495072
# loss:  122538.4799923862
# loss:  122538.01602952076
# loss:  122536.05097840224
# loss:  122535.64647975807
# loss:  122541.50877745492
# loss:  122549.94174365352
# loss:  122531.40796979926
# loss:  122555.38701428393
# weights:  [2.48479327 8.09077348 6.41050004 ... 2.33824121 1.81422006 3.305622  ]
# Optimization problem did not converge.. Check the solution returned by the optimizer.
# Returned solution is:
#      fun: 122531.40796979926
#    maxcv: 17047.18557543728
#  message: 'Did not converge to a solution satisfying the constraints. See `maxcv` for magnitude of violation.'
#     nfev: 10
#   status: 4
#  success: False
#        x: array([2.48479327, 8.09077348, 6.41050004, ..., 2.33824121, 1.81422006,
#        3.305622  ])
# Train data:
# ------------
# Train accuracy :  0.8874285714285715
# Total data points: 7000
# # non-protected examples: 4726
# # protected examples: 2274
# Non-protected in positive class: 1632 (35%)
# Protected in positive class: 397 (17%)
# P-rule is: 51%
#
# Test data:
# ------------
# Test accuracy :  0.6203333333333333
# Total data points: 3000
# # non-protected examples: 2003
# # protected examples: 997
# Non-protected in positive class: 1073 (54%)
# Protected in positive class: 441 (44%)
# P-rule is: 83%

# %%
test_adult_data.test_adult_data()
# Out:
# Looking for file 'adult.data' in the current directory...
# File found in current directory..
# Looking for file 'adult.test' in the current directory...
# File found in current directory..
# Loading only 10000 examples from the data
# Total data points: 10000
# # non-protected examples: 6742
# # protected examples: 3258
# Non-protected in positive class: 2163 (32%)
# Protected in positive class: 369 (11%)
# P-rule is: 35%
# iter:  10   lambda:  1   alpha:  0.5   kernel: rbf, method:  cobyla
# [0.16479462 0.97073217 0.48047114 ... 0.22499279 0.76112658 0.33330805]
# loss:  114602.86757089735
# loss:  114608.4242465098
# loss:  114606.49553921695
# loss:  114608.38907283654
# loss:  114605.04638976288
# loss:  114638.0480814514
# loss:  114607.10169483542
# loss:  114606.51741320641
# loss:  114606.88832435473
# loss:  114608.21125714605
# weights:  [8.83119381 0.11203745 9.26468955 ... 2.02791169 6.41507156 9.29995873]
# Optimization problem did not converge.. Check the solution returned by the optimizer.
# Returned solution is:
#      fun: 114602.86757089735
#    maxcv: 17053.361779002953
#  message: 'Did not converge to a solution satisfying the constraints. See `maxcv` for magnitude of violation.'
#     nfev: 10
#   status: 4
#  success: False
#        x: array([8.83119381, 0.11203745, 9.26468955, ..., 2.02791169, 6.41507156,
#        9.29995873])
# Train data:
# ------------
# Train accuracy :  0.5702857142857143
# Total data points: 7000
# # non-protected examples: 4710
# # protected examples: 2290
# Non-protected in positive class: 3183 (68%)
# Protected in positive class: 1333 (58%)
# P-rule is: 86%
#
# Test data:
# ------------
# Test accuracy :  0.49133333333333334
# Total data points: 3000
# # non-protected examples: 2032
# # protected examples: 968
# Non-protected in positive class: 1494 (74%)
# Protected in positive class: 644 (67%)
# P-rule is: 90%
